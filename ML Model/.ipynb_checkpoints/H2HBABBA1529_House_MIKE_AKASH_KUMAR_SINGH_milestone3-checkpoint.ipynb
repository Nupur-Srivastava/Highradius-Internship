# %% [markdown]
# # Machine Learning Model To Predict the Payment Date

# %%
#importing libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
import random
import warnings
import sklearn
import xgboost as xgb
from scipy import stats
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split , GridSearchCV,cross_val_score,cross_val_predict,cross_validate,RandomizedSearchCV
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score,max_error,r2_score,median_absolute_error,mean_squared_log_error
from sklearn.feature_selection import VarianceThreshold,SelectKBest,f_regression
from sklearn.preprocessing import MinMaxScaler,normalize,StandardScaler,RobustScaler
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.decomposition import PCA
warnings.filterwarnings("ignore")
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

pd. set_option('display.max_columns', 1000) # or 1000.
pd. set_option('display.max_rows', 1000) # or 1000.

# %%
#reading the csv file
df= pd.read_csv("data.csv")

# %%
df
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              U001  0200769623        WAL-MAR corp  2019-05-07 00:00:00
# 1              U001  0200769623  WAL-MAR associates  2019-10-17 00:00:00
# 2              U001  0200508557    FOODL foundation  2019-04-08 00:00:00
# 3              U001  0200769623         WAL-MAR llc  2020-03-03 00:00:00
# 4              U001  0200772670      ASSOCIAT trust  2019-05-01 00:00:00
# ...             ...         ...                 ...                  ...
# 49995          U001  0200726979       BJ'S  systems  2020-01-28 00:00:00
# 49996          U001  0200772595   SAFEW corporation  2019-04-29 00:00:00
# 49997          U001  0200772670         ASSOCIAT co  2019-06-13 00:00:00
# 49998          U001  0200706844               WINC                   NaN
# 49999          U001  0200771157             WEIS co  2019-01-29 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 0             2019.0  1.929179e+09   2019-04-20              20190419
# 1             2019.0  1.929962e+09   2019-10-04              20191004
# 2             2019.0  1.928971e+09   2019-03-22              20190315
# 3             2020.0  1.930549e+09   2020-02-22              20200220
# 4             2019.0  1.929168e+09   2019-04-18              20190418
# ...              ...           ...          ...                   ...
# 49995         2020.0  1.930395e+09   2020-01-13              20200113
# 49996         2019.0  1.928838e+09   2019-02-21              20190221
# 49997         2019.0  1.929387e+09   2019-05-29              20190528
# 49998         2020.0  1.930757e+09   2020-04-08              20200406
# 49999         2019.0  1.928620e+09   2019-01-14              20190114
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 0                    20190420   20190505.0              USD            RV
# 1                    20191004   20191019.0              USD            RV
# 2                    20190322   20190406.0              USD            RV
# 3                    20200222   20200308.0              USD            RV
# 4                    20190418   20190503.0              USD            RV
# ...                       ...          ...              ...           ...
# 49995                20200113   20200128.0              USD            RV
# 49996                20190221   20190427.0              USD            RV
# 49997                20190529   20190613.0              USD            RV
# 49998                20200408   20200423.0              USD            RV
# 49999                20190114   20190129.0              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 0             1.0            NaN           15112.61            20190420.0
# 1             1.0            NaN            9429.62            20191004.0
# 2             1.0            NaN            2560.91            20190322.0
# 3             1.0            NaN            6006.40            20200222.0
# 4             1.0            NaN           11905.20            20190418.0
# ...           ...            ...                ...                   ...
# 49995         1.0            NaN             206.74            20200113.0
# 49996         1.0            NaN            2588.65            20190221.0
# 49997         1.0            NaN            2611.44            20190529.0
# 49998         1.0            NaN            5880.96            20200408.0
# 49999         1.0            NaN           50470.69            20190114.0
#
#       cust_payment_terms    invoice_id  isOpen
# 0                   NAH4  1.929179e+09       0
# 1                   NAH4  1.929962e+09       0
# 2                   NAA8  1.928971e+09       0
# 3                   NAH4  1.930549e+09       0
# 4                   NAU5  1.929168e+09       0
# ...                  ...           ...     ...
# 49995               NAA8  1.930395e+09       0
# 49996               NAGD  1.928838e+09       0
# 49997               NAU5  1.929387e+09       0
# 49998               NAA8  1.930757e+09       1
# 49999               NAA8  1.928620e+09       0
#
# [50000 rows x 19 columns]

# %%
#Coverting to date format for creating target column
df['clear_date'] = pd.to_datetime(df['clear_date'])
df["due_in_date"]= pd.to_datetime(df.due_in_date,format='%Y%m%d')

# %%
#A new column is formed by subtracting the clear_date column with due_in_date column
df["delay"]=df["clear_date"] - df["due_in_date"]
df["delay"]=df["delay"]/np.timedelta64(1,"D")
df
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 0              U001  0200769623        WAL-MAR corp 2019-05-07         2019.0
# 1              U001  0200769623  WAL-MAR associates 2019-10-17         2019.0
# 2              U001  0200508557    FOODL foundation 2019-04-08         2019.0
# 3              U001  0200769623         WAL-MAR llc 2020-03-03         2020.0
# 4              U001  0200772670      ASSOCIAT trust 2019-05-01         2019.0
# ...             ...         ...                 ...        ...            ...
# 49995          U001  0200726979       BJ'S  systems 2020-01-28         2020.0
# 49996          U001  0200772595   SAFEW corporation 2019-04-29         2019.0
# 49997          U001  0200772670         ASSOCIAT co 2019-06-13         2019.0
# 49998          U001  0200706844               WINC         NaT         2020.0
# 49999          U001  0200771157             WEIS co 2019-01-29         2019.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.929179e+09   2019-04-20              20190419
# 1      1.929962e+09   2019-10-04              20191004
# 2      1.928971e+09   2019-03-22              20190315
# 3      1.930549e+09   2020-02-22              20200220
# 4      1.929168e+09   2019-04-18              20190418
# ...             ...          ...                   ...
# 49995  1.930395e+09   2020-01-13              20200113
# 49996  1.928838e+09   2019-02-21              20190221
# 49997  1.929387e+09   2019-05-29              20190528
# 49998  1.930757e+09   2020-04-08              20200406
# 49999  1.928620e+09   2019-01-14              20190114
#
#        document_create_date.1 due_in_date invoice_currency document type  \
# 0                    20190420  2019-05-05              USD            RV
# 1                    20191004  2019-10-19              USD            RV
# 2                    20190322  2019-04-06              USD            RV
# 3                    20200222  2020-03-08              USD            RV
# 4                    20190418  2019-05-03              USD            RV
# ...                       ...         ...              ...           ...
# 49995                20200113  2020-01-28              USD            RV
# 49996                20190221  2019-04-27              USD            RV
# 49997                20190529  2019-06-13              USD            RV
# 49998                20200408  2020-04-23              USD            RV
# 49999                20190114  2019-01-29              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 0             1.0            NaN           15112.61            20190420.0
# 1             1.0            NaN            9429.62            20191004.0
# 2             1.0            NaN            2560.91            20190322.0
# 3             1.0            NaN            6006.40            20200222.0
# 4             1.0            NaN           11905.20            20190418.0
# ...           ...            ...                ...                   ...
# 49995         1.0            NaN             206.74            20200113.0
# 49996         1.0            NaN            2588.65            20190221.0
# 49997         1.0            NaN            2611.44            20190529.0
# 49998         1.0            NaN            5880.96            20200408.0
# 49999         1.0            NaN           50470.69            20190114.0
#
#       cust_payment_terms    invoice_id  isOpen  delay
# 0                   NAH4  1.929179e+09       0    2.0
# 1                   NAH4  1.929962e+09       0   -2.0
# 2                   NAA8  1.928971e+09       0    2.0
# 3                   NAH4  1.930549e+09       0   -5.0
# 4                   NAU5  1.929168e+09       0   -2.0
# ...                  ...           ...     ...    ...
# 49995               NAA8  1.930395e+09       0    0.0
# 49996               NAGD  1.928838e+09       0    2.0
# 49997               NAU5  1.929387e+09       0    0.0
# 49998               NAA8  1.930757e+09       1    NaN
# 49999               NAA8  1.928620e+09       0    0.0
#
# [50000 rows x 20 columns]

# %%
#checking how many null values
df.isna().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# area_business             50000
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    2
# isOpen                        0
# delay                     10000
# dtype: int64

# %% [markdown]
# ## Removing the data points where the target value is null

# %% [markdown]
# ### Target column is the delay

# %%
main_train = df[df.delay.isnull()==False]
main_test =  df[df.delay.isnull()==True]

# %%
main_train.shape
# Out:
# (40000, 20)

# %%
main_train.isna().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                    0
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# area_business             40000
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    2
# isOpen                        0
# delay                         0
# dtype: int64

# %%
main_train
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 0              U001  0200769623        WAL-MAR corp 2019-05-07         2019.0
# 1              U001  0200769623  WAL-MAR associates 2019-10-17         2019.0
# 2              U001  0200508557    FOODL foundation 2019-04-08         2019.0
# 3              U001  0200769623         WAL-MAR llc 2020-03-03         2020.0
# 4              U001  0200772670      ASSOCIAT trust 2019-05-01         2019.0
# ...             ...         ...                 ...        ...            ...
# 49994          U001  0200769623  WAL-MAR associates 2019-11-12         2019.0
# 49995          U001  0200726979       BJ'S  systems 2020-01-28         2020.0
# 49996          U001  0200772595   SAFEW corporation 2019-04-29         2019.0
# 49997          U001  0200772670         ASSOCIAT co 2019-06-13         2019.0
# 49999          U001  0200771157             WEIS co 2019-01-29         2019.0
#
#              doc_id posting_date  document_create_date  \
# 0      1.929179e+09   2019-04-20              20190419
# 1      1.929962e+09   2019-10-04              20191004
# 2      1.928971e+09   2019-03-22              20190315
# 3      1.930549e+09   2020-02-22              20200220
# 4      1.929168e+09   2019-04-18              20190418
# ...             ...          ...                   ...
# 49994  1.930087e+09   2019-11-02              20191101
# 49995  1.930395e+09   2020-01-13              20200113
# 49996  1.928838e+09   2019-02-21              20190221
# 49997  1.929387e+09   2019-05-29              20190528
# 49999  1.928620e+09   2019-01-14              20190114
#
#        document_create_date.1 due_in_date invoice_currency document type  \
# 0                    20190420  2019-05-05              USD            RV
# 1                    20191004  2019-10-19              USD            RV
# 2                    20190322  2019-04-06              USD            RV
# 3                    20200222  2020-03-08              USD            RV
# 4                    20190418  2019-05-03              USD            RV
# ...                       ...         ...              ...           ...
# 49994                20191102  2019-11-17              USD            RV
# 49995                20200113  2020-01-28              USD            RV
# 49996                20190221  2019-04-27              USD            RV
# 49997                20190529  2019-06-13              USD            RV
# 49999                20190114  2019-01-29              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 0             1.0            NaN           15112.61            20190420.0
# 1             1.0            NaN            9429.62            20191004.0
# 2             1.0            NaN            2560.91            20190322.0
# 3             1.0            NaN            6006.40            20200222.0
# 4             1.0            NaN           11905.20            20190418.0
# ...           ...            ...                ...                   ...
# 49994         1.0            NaN           51359.76            20191102.0
# 49995         1.0            NaN             206.74            20200113.0
# 49996         1.0            NaN            2588.65            20190221.0
# 49997         1.0            NaN            2611.44            20190529.0
# 49999         1.0            NaN           50470.69            20190114.0
#
#       cust_payment_terms    invoice_id  isOpen  delay
# 0                   NAH4  1.929179e+09       0    2.0
# 1                   NAH4  1.929962e+09       0   -2.0
# 2                   NAA8  1.928971e+09       0    2.0
# 3                   NAH4  1.930549e+09       0   -5.0
# 4                   NAU5  1.929168e+09       0   -2.0
# ...                  ...           ...     ...    ...
# 49994               NAH4  1.930087e+09       0   -5.0
# 49995               NAA8  1.930395e+09       0    0.0
# 49996               NAGD  1.928838e+09       0    2.0
# 49997               NAU5  1.929387e+09       0    0.0
# 49999               NAA8  1.928620e+09       0    0.0
#
# [40000 rows x 20 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# #### Null Imputation

# %%
#Dropping the record containing null value as the invoice_id is MCAR
main_train[main_train.invoice_id.isnull()]
# Out:
#       business_code cust_number name_customer clear_date  buisness_year  \
# 29112          CA02  0140104409      LOB corp 2019-12-27         2019.0
# 38413          CA02  0140104409        LOB co 2019-05-08         2019.0
#
#              doc_id posting_date  document_create_date  \
# 29112  9.500000e+09   2019-03-29              20190329
# 38413  9.500000e+09   2019-03-29              20190329
#
#        document_create_date.1 due_in_date invoice_currency document type  \
# 29112                20181204  2018-12-14              CAD            X2
# 38413                20190220  2019-03-02              CAD            X2
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 29112         1.0            NaN             305.64            20181204.0
# 38413         1.0            NaN           14172.84            20190220.0
#
#       cust_payment_terms  invoice_id  isOpen  delay
# 29112               CA10         NaN       0  378.0
# 38413               CA10         NaN       0   67.0

# %%
main_train["doc_id"]=main_train.doc_id.astype(int)
main_train["buisness_year"]=main_train.buisness_year.astype(int)

# %%
comparison_column = np.where(main_train["doc_id"] == main_train["invoice_id"], True, False)
comparison_column
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
#drppping invoice_id as the doc_id and invoice_id are same in main_train
main_train.drop("invoice_id",axis=1,inplace=True)

# %%
#dropping area_business as it contains all null values
main_train.drop("area_business",axis=1,inplace=True)

# %% [markdown]
# ## Date and Time Conversion

# %%
main_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40000 entries, 0 to 49999
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           40000 non-null  object
#  1   cust_number             40000 non-null  object
#  2   name_customer           40000 non-null  object
#  3   clear_date              40000 non-null  datetime64[ns]
#  4   buisness_year           40000 non-null  int32
#  5   doc_id                  40000 non-null  int32
#  6   posting_date            40000 non-null  object
#  7   document_create_date    40000 non-null  int64
#  8   document_create_date.1  40000 non-null  int64
#  9   due_in_date             40000 non-null  datetime64[ns]
#  10  invoice_currency        40000 non-null  object
#  11  document type           40000 non-null  object
#  12  posting_id              40000 non-null  float64
#  13  total_open_amount       40000 non-null  float64
#  14  baseline_create_date    40000 non-null  float64
#  15  cust_payment_terms      40000 non-null  object
#  16  isOpen                  40000 non-null  int64
#  17  delay                   40000 non-null  float64
# dtypes: datetime64[ns](2), float64(4), int32(2), int64(3), object(7)
# memory usage: 5.5+ MB

# %%
main_train["posting_date"]= pd.to_datetime(main_train["posting_date"])
main_train["document_create_date"]= pd.to_datetime(main_train.document_create_date,format='%Y%m%d')
main_train["baseline_create_date"]= pd.to_datetime(main_train.baseline_create_date,format='%Y%m%d')

# %%
#renaming the column document_create_date.1 to document_create_date1 for changing it to the datetime format
main_train.rename(columns={"document_create_date.1":"document_create_date1"}, inplace=True)

# %%
main_train["document_create_date1"]= pd.to_datetime(main_train.document_create_date1,format='%Y%m%d')

# %%
main_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40000 entries, 0 to 49999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   business_code          40000 non-null  object
#  1   cust_number            40000 non-null  object
#  2   name_customer          40000 non-null  object
#  3   clear_date             40000 non-null  datetime64[ns]
#  4   buisness_year          40000 non-null  int32
#  5   doc_id                 40000 non-null  int32
#  6   posting_date           40000 non-null  datetime64[ns]
#  7   document_create_date   40000 non-null  datetime64[ns]
#  8   document_create_date1  40000 non-null  datetime64[ns]
#  9   due_in_date            40000 non-null  datetime64[ns]
#  10  invoice_currency       40000 non-null  object
#  11  document type          40000 non-null  object
#  12  posting_id             40000 non-null  float64
#  13  total_open_amount      40000 non-null  float64
#  14  baseline_create_date   40000 non-null  datetime64[ns]
#  15  cust_payment_terms     40000 non-null  object
#  16  isOpen                 40000 non-null  int64
#  17  delay                  40000 non-null  float64
# dtypes: datetime64[ns](6), float64(3), int32(2), int64(1), object(6)
# memory usage: 5.5+ MB

# %% [markdown]
# ## Duplicate/Constant column removal

# %%
#dropping document_create_date1 because it has the same values as posting_date
main_train.drop("document_create_date1",axis=1,inplace=True)

# %%
main_train.nunique()
# Out:
# business_code               6
# cust_number              1339
# name_customer            3847
# clear_date                392
# buisness_year               2
# doc_id                  36106
# posting_date              425
# document_create_date      425
# due_in_date               491
# invoice_currency            2
# document type               2
# posting_id                  1
# total_open_amount       35786
# baseline_create_date      433
# cust_payment_terms         69
# isOpen                      1
# delay                     178
# dtype: int64

# %%
main_train.business_code.value_counts()
# Out:
# U001    36216
# CA02     3145
# U013      513
# U002      117
# U005        8
# U007        1
# Name: business_code, dtype: int64

# %%
# clubbing bussiness_code with low occurance in dataset - to ensure model gets max information
main_train["business_code"]= np.where(main_train["business_code"].isin(["U005","U007"]),"Others",main_train["business_code"])

# %%
#renaming document type to document_type 
main_train.rename(columns={"document type":"document_type"}, inplace=True)

# %%
main_train.posting_id.value_counts()
# Out:
# 1.0    40000
# Name: posting_id, dtype: int64

# %%
#renaming isOpen to is_open
main_train.rename(columns={"isOpen":"is_open"}, inplace=True)

# %%
main_train.is_open.value_counts()
# Out:
# 0    40000
# Name: is_open, dtype: int64

# %%
#Removing Constant Columns ->>Columns which have same values
unique_cols =  [x for x in main_train.columns if main_train[x].nunique()==1] 
print(unique_cols)
main_train.drop(unique_cols,axis=1,inplace=True)
main_train.columns
# Out:
# ['posting_id', 'is_open']
# Index(['business_code', 'cust_number', 'name_customer', 'clear_date',
#        'buisness_year', 'doc_id', 'posting_date', 'document_create_date',
#        'due_in_date', 'invoice_currency', 'document_type', 'total_open_amount',
#        'baseline_create_date', 'cust_payment_terms', 'delay'],
#       dtype='object')

# %%
main_train
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 0              U001  0200769623        WAL-MAR corp 2019-05-07           2019
# 1              U001  0200769623  WAL-MAR associates 2019-10-17           2019
# 2              U001  0200508557    FOODL foundation 2019-04-08           2019
# 3              U001  0200769623         WAL-MAR llc 2020-03-03           2020
# 4              U001  0200772670      ASSOCIAT trust 2019-05-01           2019
# ...             ...         ...                 ...        ...            ...
# 49994          U001  0200769623  WAL-MAR associates 2019-11-12           2019
# 49995          U001  0200726979       BJ'S  systems 2020-01-28           2020
# 49996          U001  0200772595   SAFEW corporation 2019-04-29           2019
# 49997          U001  0200772670         ASSOCIAT co 2019-06-13           2019
# 49999          U001  0200771157             WEIS co 2019-01-29           2019
#
#            doc_id posting_date document_create_date due_in_date  \
# 0      1929179048   2019-04-20           2019-04-19  2019-05-05
# 1      1929961839   2019-10-04           2019-10-04  2019-10-19
# 2      1928971348   2019-03-22           2019-03-15  2019-04-06
# 3      1930549049   2020-02-22           2020-02-20  2020-03-08
# 4      1929168485   2019-04-18           2019-04-18  2019-05-03
# ...           ...          ...                  ...         ...
# 49994  1930086848   2019-11-02           2019-11-01  2019-11-17
# 49995  1930394925   2020-01-13           2020-01-13  2020-01-28
# 49996  1928838009   2019-02-21           2019-02-21  2019-04-27
# 49997  1929386740   2019-05-29           2019-05-28  2019-06-13
# 49999  1928619839   2019-01-14           2019-01-14  2019-01-29
#
#       invoice_currency document_type  total_open_amount baseline_create_date  \
# 0                  USD            RV           15112.61           2019-04-20
# 1                  USD            RV            9429.62           2019-10-04
# 2                  USD            RV            2560.91           2019-03-22
# 3                  USD            RV            6006.40           2020-02-22
# 4                  USD            RV           11905.20           2019-04-18
# ...                ...           ...                ...                  ...
# 49994              USD            RV           51359.76           2019-11-02
# 49995              USD            RV             206.74           2020-01-13
# 49996              USD            RV            2588.65           2019-02-21
# 49997              USD            RV            2611.44           2019-05-29
# 49999              USD            RV           50470.69           2019-01-14
#
#       cust_payment_terms  delay
# 0                   NAH4    2.0
# 1                   NAH4   -2.0
# 2                   NAA8    2.0
# 3                   NAH4   -5.0
# 4                   NAU5   -2.0
# ...                  ...    ...
# 49994               NAH4   -5.0
# 49995               NAA8    0.0
# 49996               NAGD    2.0
# 49997               NAU5    0.0
# 49999               NAA8    0.0
#
# [40000 rows x 15 columns]

# %%
#dropping invoice_currency column as business_code has the details of whether the amount is USD or CAD
main_train.drop("invoice_currency",axis=1,inplace=True)

# %% [markdown]
# #### Finding & Removing duplicate records in rows

# %%
main_train=main_train.drop_duplicates(keep='first')
main_train.shape
# Out:
# (39193, 14)

# %% [markdown]
# ### Sorting the data by posting_date

# %%
main_train.sort_values(by=["posting_date"],inplace=True)

# %%
main_train
# Out:
#       business_code cust_number     name_customer clear_date  buisness_year  \
# 8212           U001  0200744019           TARG us 2019-01-22           2019
# 6062           U001  0200769623        WAL-MAR co 2019-01-17           2019
# 49831          U001  0200744019      TARG systems 2019-01-18           2019
# 34965          U001  0200726979  BJ'S  foundation 2019-01-15           2019
# 36575          U001  0200769623     WAL-MAR trust 2019-01-10           2019
# ...             ...         ...               ...        ...            ...
# 1943           U001  0200762950              HAR  2020-03-10           2020
# 41465          CA02  0140106249     FINDLAY trust 2020-03-11           2020
# 34039          U001  0200769623     WAL-MAR trust 2020-03-17           2020
# 12589          U001  0200739534    OK corporation 2020-03-13           2020
# 37227          U001  0200956366           RICH in 2020-03-06           2020
#
#            doc_id posting_date document_create_date due_in_date document_type  \
# 8212   1928537219   2018-12-30           2018-12-29  2019-01-14            RV
# 6062   1928543334   2018-12-30           2018-12-30  2019-01-14            RV
# 49831  1928539833   2018-12-30           2018-12-29  2019-01-14            RV
# 34965  1928540822   2018-12-30           2018-12-29  2019-01-14            RV
# 36575  1928542166   2018-12-30           2018-12-30  2019-01-14            RV
# ...           ...          ...                  ...         ...           ...
# 1943   1930562576   2020-02-26           2020-02-24  2020-03-12            RV
# 41465 -2147483648   2020-02-27           2020-02-27  2020-03-10            RV
# 34039  1930567788   2020-02-27           2020-02-25  2020-03-13            RV
# 12589  1930580801   2020-02-27           2020-02-27  2020-03-13            RV
# 37227  1930580236   2020-02-27           2020-02-27  2020-03-13            RV
#
#        total_open_amount baseline_create_date cust_payment_terms  delay
# 8212            17612.00           2018-12-30               NAA8    8.0
# 6062            26851.14           2018-12-30               NAH4    3.0
# 49831           39713.18           2018-12-30               NAA8    4.0
# 34965             321.54           2018-12-30               NAA8    1.0
# 36575            3748.84           2018-12-30               NAH4   -4.0
# ...                  ...                  ...                ...    ...
# 1943           149803.12           2020-02-26               NAA8   -2.0
# 41465           12104.10           2020-02-29               CA10    1.0
# 34039           10401.63           2020-02-27               NAH4    4.0
# 12589            5434.31           2020-02-27               NAA8    0.0
# 37227           51919.56           2020-02-27               NAA8   -7.0
#
# [39193 rows x 14 columns]

# %%
#removing baseline_create_date as it has the same values of posting_date
main_train.drop("baseline_create_date",axis=1,inplace=True)
main_train
#removing document_type as it has an array of same values "RV".
main_train.drop("document_type",axis=1,inplace=True)

# %% [markdown]
# ### Split Data

# %% [markdown]
# ##### splitting the main_train data into Train,Validation and test

# %%
from sklearn.model_selection import train_test_split

# %%
X= main_train.drop(["delay"],axis=1)

# %%
y=main_train["delay"]

# %%
#splitting the data first into two part -- doing a 70:30 split i.e 30% data fed to intermediate test data set
X_train,X_inter_test,y_train,y_inter_test=train_test_split(X,y,test_size=0.3,random_state=0,shuffle=False)

# %%
X_train.shape,X_inter_test.shape
# Out:
# ((27435, 11), (11758, 11))

# %%
#splitting the data first into two part -- doing a 15:15 split i.e 15% data fed to test data set
X_val,X_test,y_val,y_test = train_test_split(X_inter_test,y_inter_test,test_size=0.5,random_state=0,shuffle=False)

# %%
X_train.shape ,X_val.shape ,X_test.shape
# Out:
# ((27435, 11), (5879, 11), (5879, 11))

# %% [markdown]
# # EDA

# %%
# distribution of the target column 
# right skewed distribution
# outliers present but not that significant , hence 
sns.distplot(y_train)

# %%
X_train.merge(y_train,on = X_train.index)
# Out:
#        key_0 business_code cust_number       name_customer clear_date  \
# 0       8212          U001  0200744019             TARG us 2019-01-22
# 1       6062          U001  0200769623          WAL-MAR co 2019-01-17
# 2      49831          U001  0200744019        TARG systems 2019-01-18
# 3      34965          U001  0200726979    BJ'S  foundation 2019-01-15
# 4      36575          U001  0200769623       WAL-MAR trust 2019-01-10
# ...      ...           ...         ...                 ...        ...
# 27430  25364          U001      CCCA02        KRAFT  trust 2019-11-27
# 27431   8078          U001  0200875006   KROGER foundation 2019-10-23
# 27432  21638          U001  0200799538          UNITE corp 2019-10-24
# 27433  11334          U001  0200769623  WAL-MAR foundation 2019-10-24
# 27434  46834          U001  0200762301   C&S WH foundation 2019-10-23
#
#        buisness_year      doc_id posting_date document_create_date  \
# 0               2019  1928537219   2018-12-30           2018-12-29
# 1               2019  1928543334   2018-12-30           2018-12-30
# 2               2019  1928539833   2018-12-30           2018-12-29
# 3               2019  1928540822   2018-12-30           2018-12-29
# 4               2019  1928542166   2018-12-30           2018-12-30
# ...              ...         ...          ...                  ...
# 27430           2019  1929983039   2019-10-08           2019-10-08
# 27431           2019  1929988279   2019-10-08           2019-10-08
# 27432           2019  1929984264   2019-10-08           2019-10-08
# 27433           2019  1929981935   2019-10-08           2019-10-07
# 27434           2019  1929983693   2019-10-08           2019-10-08
#
#       due_in_date  total_open_amount cust_payment_terms  delay
# 0      2019-01-14           17612.00               NAA8    8.0
# 1      2019-01-14           26851.14               NAH4    3.0
# 2      2019-01-14           39713.18               NAA8    4.0
# 3      2019-01-14             321.54               NAA8    1.0
# 4      2019-01-14            3748.84               NAH4   -4.0
# ...           ...                ...                ...    ...
# 27430  2019-11-12           14223.60               NAG2   15.0
# 27431  2019-10-23           80942.68               NAA8    0.0
# 27432  2019-10-23           64576.86               NAA8    1.0
# 27433  2019-10-23            7341.48               NAH4    1.0
# 27434  2019-10-23           95437.99               NAC6    0.0
#
# [27435 rows x 13 columns]

# %%
sns.scatterplot(data = X_train.merge(y_train,on=X_train.index), x = "delay" , y = "clear_date")

# %%
sns.scatterplot(data = X_train.merge(y_train,on=X_train.index), x = "delay" , y = "total_open_amount")

# %% [markdown]
# #### Frequency Table

# %%
coun_t  = X_train.nunique().to_frame(name = 'Counts')
coun_t
# Out:
#                       Counts
# business_code              5
# cust_number             1228
# name_customer           3305
# clear_date               284
# buisness_year              1
# doc_id                 25259
# posting_date             283
# document_create_date     286
# due_in_date              343
# total_open_amount      25246
# cust_payment_terms        62

# %% [markdown]
# #### Mode - Most Frequently occuring Element

# %%
X_train[['buisness_year']].agg(pd.Series.mode)
# Out:
#    buisness_year
# 0           2019

# %% [markdown]
# #### Median - Ordinal Variables

# %%
X_train[['buisness_year']].agg(np.median).to_frame()
# Out:
#                     0
# buisness_year  2019.0

# %% [markdown]
# #### Mean and Standard Deviation - interval level variables (total_open_amount)

# %%
X_train['total_open_amount'].agg(['mean','std']).to_frame()
# Out:
#       total_open_amount
# mean       31545.701880
# std        39659.017227

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ##### Changing values to int or float format

# %%
from sklearn.preprocessing import LabelEncoder

# %%
#Encoding the values of name_customer to name_customer_enc using LabelEncoder
name_customer_enc = LabelEncoder()
name_customer_enc.fit(X_train["name_customer"])
X_train["name_customer_enc"]=name_customer_enc.transform(X_train["name_customer"])

# %%
name_customer_enc.fit(X_test["name_customer"])
X_test["name_customer_enc"]=name_customer_enc.transform(X_test["name_customer"])

# %%
name_customer_enc.fit(X_val["name_customer"])
X_val["name_customer_enc"]=name_customer_enc.transform(X_val["name_customer"])

# %%
#dropping the values of name customer in train,val and test
X_train.drop(["name_customer"],inplace=True,axis=1)
X_val.drop(["name_customer"],inplace=True,axis=1)
X_test.drop(["name_customer"],inplace=True,axis=1)

# %%
#creating a function dropfet for dropping the future values of X_train,X_val,X_test
def dropfet(col , traindf = X_train,valdf =X_val,testdf =X_test):
    traindf.drop(col,inplace=True,axis=1)
    valdf.drop(col,inplace=True,axis=1)
    testdf.drop(col,inplace=True,axis=1)
    return traindf,valdf,testdf

# %% [markdown]
# ### Changing the date values into seperate columns as Year, Day and month

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27435 entries, 8212 to 46834
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   business_code         27435 non-null  object
#  1   cust_number           27435 non-null  object
#  2   clear_date            27435 non-null  datetime64[ns]
#  3   buisness_year         27435 non-null  int32
#  4   doc_id                27435 non-null  int32
#  5   posting_date          27435 non-null  datetime64[ns]
#  6   document_create_date  27435 non-null  datetime64[ns]
#  7   due_in_date           27435 non-null  datetime64[ns]
#  8   total_open_amount     27435 non-null  float64
#  9   cust_payment_terms    27435 non-null  object
#  10  name_customer_enc     27435 non-null  int32
# dtypes: datetime64[ns](4), float64(1), int32(3), object(3)
# memory usage: 2.2+ MB

# %%
X_train["year_posting_date"]= X_train["posting_date"].dt.year
X_val["year_posting_date"]= X_val["posting_date"].dt.year
X_test["week_posting_date"]= X_test["posting_date"].dt.year

X_train["day_posting_date"]= X_train["posting_date"].dt.day
X_val["day_posting_day"]= X_val["posting_date"].dt.day
X_test["day_posting_day"]= X_test["posting_date"].dt.day

X_train["month_posting_date"]= X_train["posting_date"].dt.month
X_val["month_posting_date"]= X_val["posting_date"].dt.month
X_test["month_posting_date"]= X_test["posting_date"].dt.month

# %%
X_train,X_val,X_test = dropfet(["posting_date"])

# %%
X_train["year_due_in_date"]= X_train["due_in_date"].dt.year
X_val["year_due_in_date"]= X_val["due_in_date"].dt.year
X_test["year_due_in_date"]= X_test["due_in_date"].dt.year

X_train["day_due_in_date"]= X_train["due_in_date"].dt.day
X_val["day_due_in_date"]= X_val["due_in_date"].dt.day
X_test["day_due_in_date"]= X_test["due_in_date"].dt.day

X_train["month_due_in_date"]= X_train["due_in_date"].dt.month
X_val["month_due_in_date"]= X_val["due_in_date"].dt.month
X_test["month_due_in_date"]= X_test["due_in_date"].dt.month

# %%
X_train,X_val,X_test = dropfet(["due_in_date"])

# %%
X_train["year_document_create_date"]= X_train["document_create_date"].dt.year
X_val["year_document_create_date"]= X_val["document_create_date"].dt.year
X_test["year_document_create_date"]= X_test["document_create_date"].dt.year

X_train["day_document_create_date"]= X_train["document_create_date"].dt.day
X_val["day_document_create_date"]= X_val["document_create_date"].dt.day
X_test["day_document_create_date"]= X_test["document_create_date"].dt.day

X_train["month_document_create_date"]= X_train["document_create_date"].dt.month
X_val["month_document_create_date"]= X_val["document_create_date"].dt.month
X_test["month_document_create_date"]= X_test["document_create_date"].dt.month

# %%
X_train,X_val,X_test = dropfet(["document_create_date"])

# %%
#Encoding the values of cust_payment_terms to cust_payment_terms_enc using LabelEncoder
cust_payment_terms_enc = LabelEncoder()
cust_payment_terms_enc.fit(X_train["cust_payment_terms"])
X_train["cust_payment_terms_enc"]=cust_payment_terms_enc.transform(X_train["cust_payment_terms"])

# %%
cust_payment_terms_enc.fit(X_val["cust_payment_terms"])
X_val["cust_payment_terms_enc"]=cust_payment_terms_enc.transform(X_val["cust_payment_terms"])
cust_payment_terms_enc.fit(X_test["cust_payment_terms"])
X_test["cust_payment_terms_enc"]=cust_payment_terms_enc.transform(X_test["cust_payment_terms"])

# %%
X_train,X_val,X_test = dropfet(["cust_payment_terms"])

# %% [markdown]
# #### Splitting the mixed column to Labels's and numericals seperately

# %%
mixed_cust_num="cust_number"
mixed_num_in_cust_num= mixed_cust_num + "_numerical"
mixed_label_in_cust_num= mixed_cust_num + "_label"

# %%
X_train[mixed_num_in_cust_num]=X_train[mixed_cust_num].str.extract('(\d+)')

# %%
X_train[mixed_label_in_cust_num]=X_train[mixed_cust_num].str[:3]

# %%
X_train["cust_number_numerical"]=X_train.cust_number_numerical.astype(int)

# %%
X_val[mixed_num_in_cust_num]=X_val[mixed_cust_num].str.extract('(\d+)')
X_val[mixed_label_in_cust_num]=X_val[mixed_cust_num].str[:3]
X_val["cust_number_numerical"]=X_val.cust_number_numerical.astype(int)

X_test[mixed_num_in_cust_num]=X_test[mixed_cust_num].str.extract('(\d+)')
X_test[mixed_label_in_cust_num]=X_test[mixed_cust_num].str[:3]
X_test["cust_number_numerical"]=X_test.cust_number_numerical.astype(int)

# %%
cust_number_label_enc = LabelEncoder()
cust_number_label_enc.fit(X_train["cust_number_label"])
X_train["cust_number_label_enc"]=cust_number_label_enc.transform(X_train["cust_number_label"])

# %%
cust_number_label_enc.fit(X_val["cust_number_label"])
X_val["cust_number_label_enc"]=cust_number_label_enc.transform(X_val["cust_number_label"])
cust_number_label_enc.fit(X_test["cust_number_label"])
X_test["cust_number_label_enc"]=cust_number_label_enc.transform(X_test["cust_number_label"])

# %%
X_train,X_val,X_test = dropfet(["cust_number"])
X_train,X_val,X_test = dropfet(["cust_number_label"])

# %%
#Encoding the values of business_code to business_code_enc using LabelEncoder
business_code_enc = LabelEncoder()
business_code_enc.fit(X_train["business_code"])
X_train["business_code_enc"]=business_code_enc.transform(X_train["business_code"])

business_code_enc.fit(X_val["business_code"])
X_val["business_code_enc"]=business_code_enc.transform(X_val["business_code"])

business_code_enc.fit(X_test["business_code"])
X_test["business_code_enc"]=business_code_enc.transform(X_test["business_code"])

# %%
X_train,X_val,X_test = dropfet(["business_code"])

# %%
X_train,X_val,X_test = dropfet(["clear_date"])

# %% [markdown]
# ## Feature Selection

# %%
X_train.merge(y_train,on=X_train.index).corr()
# Out:
#                                key_0  buisness_year    doc_id  \
# key_0                       1.000000            NaN -0.001556
# buisness_year                    NaN            NaN       NaN
# doc_id                     -0.001556            NaN  1.000000
# total_open_amount           0.002080            NaN -0.188213
# name_customer_enc           0.001338            NaN  0.013856
# year_posting_date           0.010163            NaN -0.008047
# day_posting_date            0.016573            NaN -0.001969
# month_posting_date         -0.015014            NaN -0.010286
# year_due_in_date           -0.008731            NaN  0.011170
# day_due_in_date            -0.011541            NaN  0.003890
# month_due_in_date          -0.009042            NaN  0.001128
# year_document_create_date   0.009260            NaN -0.015879
# day_document_create_date    0.013589            NaN -0.004607
# month_document_create_date -0.015166            NaN -0.009515
# cust_payment_terms_enc     -0.006536            NaN  0.517301
# cust_number_numerical       0.001206            NaN  0.315135
# cust_number_label_enc      -0.001876            NaN  0.181252
# business_code_enc          -0.001751            NaN  0.916804
# delay                       0.010462            NaN -0.129938
#
#                             total_open_amount  name_customer_enc  \
# key_0                                0.002080           0.001338
# buisness_year                             NaN                NaN
# doc_id                              -0.188213           0.013856
# total_open_amount                    1.000000          -0.009746
# name_customer_enc                   -0.009746           1.000000
# year_posting_date                   -0.002277          -0.020990
# day_posting_date                     0.014645           0.007777
# month_posting_date                   0.009032          -0.008406
# year_due_in_date                    -0.007334          -0.003341
# day_due_in_date                     -0.010560           0.005014
# month_due_in_date                    0.000731          -0.021261
# year_document_create_date            0.004240          -0.025256
# day_document_create_date             0.019144           0.006897
# month_document_create_date           0.008168          -0.005819
# cust_payment_terms_enc              -0.201921           0.089416
# cust_number_numerical               -0.016310           0.118321
# cust_number_label_enc               -0.072495          -0.015670
# business_code_enc                   -0.181884          -0.009364
# delay                                0.007442          -0.038188
#
#                             year_posting_date  day_posting_date  \
# key_0                                0.010163          0.016573
# buisness_year                             NaN               NaN
# doc_id                              -0.008047         -0.001969
# total_open_amount                   -0.002277          0.014645
# name_customer_enc                   -0.020990          0.007777
# year_posting_date                    1.000000         -0.114636
# day_posting_date                    -0.114636          1.000000
# month_posting_date                  -0.173741         -0.048904
# year_due_in_date                     0.000000         -0.010586
# day_due_in_date                      0.009838         -0.367415
# month_due_in_date                    0.119758          0.063735
# year_document_create_date            0.764795         -0.035840
# day_document_create_date            -0.101947          0.828302
# month_document_create_date          -0.163935         -0.051789
# cust_payment_terms_enc              -0.000989          0.009827
# cust_number_numerical               -0.015765          0.000157
# cust_number_label_enc                0.018324         -0.013381
# business_code_enc                   -0.006387          0.003762
# delay                                0.005403         -0.007038
#
#                             month_posting_date  year_due_in_date  \
# key_0                                -0.015014         -0.008731
# buisness_year                              NaN               NaN
# doc_id                               -0.010286          0.011170
# total_open_amount                     0.009032         -0.007334
# name_customer_enc                    -0.008406         -0.003341
# year_posting_date                    -0.173741          0.000000
# day_posting_date                     -0.048904         -0.010586
# month_posting_date                    1.000000          0.015871
# year_due_in_date                      0.015871          1.000000
# day_due_in_date                       0.027711         -0.004878
# month_due_in_date                     0.930759         -0.024775
# year_document_create_date            -0.079407          0.000000
# day_document_create_date             -0.037294         -0.010575
# month_document_create_date            0.972101          0.015801
# cust_payment_terms_enc                0.004063          0.023276
# cust_number_numerical                -0.001360         -0.009665
# cust_number_label_enc                -0.026134         -0.004987
# business_code_enc                    -0.009102          0.010035
# delay                                -0.016607         -0.125987
#
#                             day_due_in_date  month_due_in_date  \
# key_0                             -0.011541          -0.009042
# buisness_year                           NaN                NaN
# doc_id                             0.003890           0.001128
# total_open_amount                 -0.010560           0.000731
# name_customer_enc                  0.005014          -0.021261
# year_posting_date                  0.009838           0.119758
# day_posting_date                  -0.367415           0.063735
# month_posting_date                 0.027711           0.930759
# year_due_in_date                  -0.004878          -0.024775
# day_due_in_date                    1.000000          -0.115669
# month_due_in_date                 -0.115669           1.000000
# year_document_create_date          0.006855           0.150413
# day_document_create_date          -0.374518           0.061157
# month_document_create_date         0.028537           0.905517
# cust_payment_terms_enc             0.000606           0.038957
# cust_number_numerical             -0.005042          -0.015188
# cust_number_label_enc              0.010562          -0.020252
# business_code_enc                  0.006079           0.015715
# delay                             -0.007702          -0.036152
#
#                             year_document_create_date  \
# key_0                                        0.009260
# buisness_year                                     NaN
# doc_id                                      -0.015879
# total_open_amount                            0.004240
# name_customer_enc                           -0.025256
# year_posting_date                            0.764795
# day_posting_date                            -0.035840
# month_posting_date                          -0.079407
# year_due_in_date                             0.000000
# day_due_in_date                              0.006855
# month_due_in_date                            0.150413
# year_document_create_date                    1.000000
# day_document_create_date                    -0.140086
# month_document_create_date                  -0.218734
# cust_payment_terms_enc                      -0.000734
# cust_number_numerical                       -0.016973
# cust_number_label_enc                        0.015476
# business_code_enc                           -0.015428
# delay                                        0.004495
#
#                             day_document_create_date  \
# key_0                                       0.013589
# buisness_year                                    NaN
# doc_id                                     -0.004607
# total_open_amount                           0.019144
# name_customer_enc                           0.006897
# year_posting_date                          -0.101947
# day_posting_date                            0.828302
# month_posting_date                         -0.037294
# year_due_in_date                           -0.010575
# day_due_in_date                            -0.374518
# month_due_in_date                           0.061157
# year_document_create_date                  -0.140086
# day_document_create_date                    1.000000
# month_document_create_date                 -0.032278
# cust_payment_terms_enc                      0.011675
# cust_number_numerical                       0.002507
# cust_number_label_enc                      -0.010374
# business_code_enc                           0.001561
# delay                                      -0.011054
#
#                             month_document_create_date  \
# key_0                                        -0.015166
# buisness_year                                      NaN
# doc_id                                       -0.009515
# total_open_amount                             0.008168
# name_customer_enc                            -0.005819
# year_posting_date                            -0.163935
# day_posting_date                             -0.051789
# month_posting_date                            0.972101
# year_due_in_date                              0.015801
# day_due_in_date                               0.028537
# month_due_in_date                             0.905517
# year_document_create_date                    -0.218734
# day_document_create_date                     -0.032278
# month_document_create_date                    1.000000
# cust_payment_terms_enc                        0.001533
# cust_number_numerical                         0.001694
# cust_number_label_enc                        -0.028759
# business_code_enc                            -0.008603
# delay                                        -0.016514
#
#                             cust_payment_terms_enc  cust_number_numerical  \
# key_0                                    -0.006536               0.001206
# buisness_year                                  NaN                    NaN
# doc_id                                    0.517301               0.315135
# total_open_amount                        -0.201921              -0.016310
# name_customer_enc                         0.089416               0.118321
# year_posting_date                        -0.000989              -0.015765
# day_posting_date                          0.009827               0.000157
# month_posting_date                        0.004063              -0.001360
# year_due_in_date                          0.023276              -0.009665
# day_due_in_date                           0.000606              -0.005042
# month_due_in_date                         0.038957              -0.015188
# year_document_create_date                -0.000734              -0.016973
# day_document_create_date                  0.011675               0.002507
# month_document_create_date                0.001533               0.001694
# cust_payment_terms_enc                    1.000000              -0.140924
# cust_number_numerical                    -0.140924               1.000000
# cust_number_label_enc                     0.403158              -0.537924
# business_code_enc                         0.581165               0.180396
# delay                                     0.077723              -0.398635
#
#                             cust_number_label_enc  business_code_enc     delay
# key_0                                   -0.001876          -0.001751  0.010462
# buisness_year                                 NaN                NaN       NaN
# doc_id                                   0.181252           0.916804 -0.129938
# total_open_amount                       -0.072495          -0.181884  0.007442
# name_customer_enc                       -0.015670          -0.009364 -0.038188
# year_posting_date                        0.018324          -0.006387  0.005403
# day_posting_date                        -0.013381           0.003762 -0.007038
# month_posting_date                      -0.026134          -0.009102 -0.016607
# year_due_in_date                        -0.004987           0.010035 -0.125987
# day_due_in_date                          0.010562           0.006079 -0.007702
# month_due_in_date                       -0.020252           0.015715 -0.036152
# year_document_create_date                0.015476          -0.015428  0.004495
# day_document_create_date                -0.010374           0.001561 -0.011054
# month_document_create_date              -0.028759          -0.008603 -0.016514
# cust_payment_terms_enc                   0.403158           0.581165  0.077723
# cust_number_numerical                   -0.537924           0.180396 -0.398635
# cust_number_label_enc                    1.000000           0.179256  0.330645
# business_code_enc                        0.179256           1.000000 -0.078386
# delay                                    0.330645          -0.078386  1.000000

# %%
#Plotting colormap
colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title("Pearson Correlation Features",y=1.05,size=15)
sns.heatmap(X_train.merge(y_train,on=X_train.index).corr(),linewidths=0.1,vmax=1.0,
           square=True, cmap=colormap, linecolor="white", annot=True)

# %% [markdown]
# # Modelling

# %%
from sklearn.linear_model import LinearRegression
base_model = LinearRegression()
base_model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# #### Linear regression algorithm

# %%
y_predict=base_model.predict(X_val)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_val, y_predict, squared=False)
# Out:
# 8.49188727273973

# %%
pd.DataFrame(zip(y_val,y_predict),columns=["clear_date_predicted","delay"])
# Out:
#       clear_date_predicted     delay
# 0                    -11.0 -8.376293
# 1                     -8.0 -3.580223
# 2                      0.0 -4.564343
# 3                      0.0  0.489522
# 4                     -5.0 -3.751004
# ...                    ...       ...
# 5874                  -1.0 -3.810091
# 5875                   2.0 -4.400632
# 5876                  -5.0 -4.744749
# 5877                  -2.0 -3.902029
# 5878                  -2.0  5.755082
#
# [5879 rows x 2 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0 , max_depth=5)

# %% [markdown]
# #### Decision tree regression algorithm

# %%
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=5,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
predicted2 =regressor.predict(X_val)

# %%
mean_squared_error(y_val,predicted2,squared=False)
# Out:
# 8.26025436457224

# %%
y_predict_test = regressor.predict(X_test)
mean_squared_error(y_test, y_predict_test, squared=False)
# Out:
# 12.334600958286126

# %% [markdown]
# # The lost data

# %%
main_test
# Out:
#       business_code cust_number       name_customer clear_date  buisness_year  \
# 6              U001   200726979              BJ'S          NaT         2020.0
# 7              U001   200780383     MEIJ associates        NaT         2020.0
# 17             U001  0200776463       KROGE systems        NaT         2020.0
# 24             U001   200769623        WAL-MAR corp        NaT         2020.0
# 29             U001  0200769623          WAL-MAR co        NaT         2020.0
# ...             ...         ...                 ...        ...            ...
# 49979          U001  0200418007       AM foundation        NaT         2020.0
# 49981          U001  0200769623  WAL-MAR associates        NaT         2020.0
# 49986          U001  0200759878      SA corporation        NaT         2020.0
# 49987          U001  0200769623  WAL-MAR associates        NaT         2020.0
# 49998          U001  0200706844               WINC         NaT         2020.0
#
#              doc_id posting_date  document_create_date  \
# 6      1.930655e+09   2020-03-17              20200316
# 7      1.930855e+09   2020-05-04              20200503
# 17     1.930826e+09   2020-04-24              20200425
# 24     1.930677e+09   2020-03-23              20200321
# 29     1.930705e+09   2020-03-26              20200326
# ...             ...          ...                   ...
# 49979  1.930780e+09   2020-04-15              20200413
# 49981  1.930599e+09   2020-03-05              20200304
# 49986  1.930666e+09   2020-03-19              20200318
# 49987  1.930862e+09   2020-05-07              20200506
# 49998  1.930757e+09   2020-04-08              20200406
#
#        document_create_date.1 due_in_date invoice_currency document type  \
# 6                    20200317  2020-04-01              USD            RV
# 7                    20200504  2020-05-19              USD            RV
# 17                   20200424  2020-05-09              USD            RV
# 24                   20200323  2020-04-07              USD            RV
# 29                   20200326  2020-04-10              USD            RV
# ...                       ...         ...              ...           ...
# 49979                20200415  2020-04-30              USD            RV
# 49981                20200305  2020-03-20              USD            RV
# 49986                20200319  2020-04-03              USD            RV
# 49987                20200507  2020-05-22              USD            RV
# 49998                20200408  2020-04-23              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 6             1.0            NaN             387.69            20200317.0
# 7             1.0            NaN           41352.28            20200504.0
# 17            1.0            NaN            2915.48            20200424.0
# 24            1.0            NaN           13902.00            20200323.0
# 29            1.0            NaN            3270.04            20200326.0
# ...           ...            ...                ...                   ...
# 49979         1.0            NaN             644.80            20200415.0
# 49981         1.0            NaN           16463.85            20200305.0
# 49986         1.0            NaN           47269.22            20200319.0
# 49987         1.0            NaN           25109.62            20200507.0
# 49998         1.0            NaN            5880.96            20200408.0
#
#       cust_payment_terms    invoice_id  isOpen  delay
# 6                   NAA8  1.930655e+09       1    NaN
# 7                   NAA8  1.930855e+09       1    NaN
# 17                  NAA8  1.930826e+09       1    NaN
# 24                  NAH4  1.930677e+09       1    NaN
# 29                  NAH4  1.930705e+09       1    NaN
# ...                  ...           ...     ...    ...
# 49979               NAA8  1.930780e+09       1    NaN
# 49981               NAH4  1.930599e+09       1    NaN
# 49986               NAH4  1.930666e+09       1    NaN
# 49987               NAH4  1.930862e+09       1    NaN
# 49998               NAA8  1.930757e+09       1    NaN
#
# [10000 rows x 20 columns]

# %%
main_test.isna().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# area_business             10000
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    0
# isOpen                        0
# delay                     10000
# dtype: int64

# %% [markdown]
# ### Doing the same preprocessing and Feature engineering steps

# %%
#Removing the target clear date and clear date from X_main_test
X_main_test= main_test.drop(["delay","clear_date"],axis =1)
X_main_test
# Out:
#       business_code cust_number       name_customer  buisness_year  \
# 6              U001   200726979              BJ'S           2020.0
# 7              U001   200780383     MEIJ associates         2020.0
# 17             U001  0200776463       KROGE systems         2020.0
# 24             U001   200769623        WAL-MAR corp         2020.0
# 29             U001  0200769623          WAL-MAR co         2020.0
# ...             ...         ...                 ...            ...
# 49979          U001  0200418007       AM foundation         2020.0
# 49981          U001  0200769623  WAL-MAR associates         2020.0
# 49986          U001  0200759878      SA corporation         2020.0
# 49987          U001  0200769623  WAL-MAR associates         2020.0
# 49998          U001  0200706844               WINC          2020.0
#
#              doc_id posting_date  document_create_date  \
# 6      1.930655e+09   2020-03-17              20200316
# 7      1.930855e+09   2020-05-04              20200503
# 17     1.930826e+09   2020-04-24              20200425
# 24     1.930677e+09   2020-03-23              20200321
# 29     1.930705e+09   2020-03-26              20200326
# ...             ...          ...                   ...
# 49979  1.930780e+09   2020-04-15              20200413
# 49981  1.930599e+09   2020-03-05              20200304
# 49986  1.930666e+09   2020-03-19              20200318
# 49987  1.930862e+09   2020-05-07              20200506
# 49998  1.930757e+09   2020-04-08              20200406
#
#        document_create_date.1 due_in_date invoice_currency document type  \
# 6                    20200317  2020-04-01              USD            RV
# 7                    20200504  2020-05-19              USD            RV
# 17                   20200424  2020-05-09              USD            RV
# 24                   20200323  2020-04-07              USD            RV
# 29                   20200326  2020-04-10              USD            RV
# ...                       ...         ...              ...           ...
# 49979                20200415  2020-04-30              USD            RV
# 49981                20200305  2020-03-20              USD            RV
# 49986                20200319  2020-04-03              USD            RV
# 49987                20200507  2020-05-22              USD            RV
# 49998                20200408  2020-04-23              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 6             1.0            NaN             387.69            20200317.0
# 7             1.0            NaN           41352.28            20200504.0
# 17            1.0            NaN            2915.48            20200424.0
# 24            1.0            NaN           13902.00            20200323.0
# 29            1.0            NaN            3270.04            20200326.0
# ...           ...            ...                ...                   ...
# 49979         1.0            NaN             644.80            20200415.0
# 49981         1.0            NaN           16463.85            20200305.0
# 49986         1.0            NaN           47269.22            20200319.0
# 49987         1.0            NaN           25109.62            20200507.0
# 49998         1.0            NaN            5880.96            20200408.0
#
#       cust_payment_terms    invoice_id  isOpen
# 6                   NAA8  1.930655e+09       1
# 7                   NAA8  1.930855e+09       1
# 17                  NAA8  1.930826e+09       1
# 24                  NAH4  1.930677e+09       1
# 29                  NAH4  1.930705e+09       1
# ...                  ...           ...     ...
# 49979               NAA8  1.930780e+09       1
# 49981               NAH4  1.930599e+09       1
# 49986               NAH4  1.930666e+09       1
# 49987               NAH4  1.930862e+09       1
# 49998               NAA8  1.930757e+09       1
#
# [10000 rows x 18 columns]

# %%
# Also removing both from main_test
main_test.drop(["delay","clear_date"],inplace=True,axis=1)

# %%
#Changing the dtype of the following
X_main_test["doc_id"]=X_main_test.doc_id.astype(int)
X_main_test["buisness_year"]=X_main_test.buisness_year.astype(int)

# %%
X_main_test.drop("invoice_id",axis=1,inplace=True) #removing invoice id

# %%
X_main_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 6 to 49998
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           10000 non-null  object
#  1   cust_number             10000 non-null  object
#  2   name_customer           10000 non-null  object
#  3   buisness_year           10000 non-null  int32
#  4   doc_id                  10000 non-null  int32
#  5   posting_date            10000 non-null  object
#  6   document_create_date    10000 non-null  int64
#  7   document_create_date.1  10000 non-null  int64
#  8   due_in_date             10000 non-null  datetime64[ns]
#  9   invoice_currency        10000 non-null  object
#  10  document type           10000 non-null  object
#  11  posting_id              10000 non-null  float64
#  12  area_business           0 non-null      float64
#  13  total_open_amount       10000 non-null  float64
#  14  baseline_create_date    10000 non-null  float64
#  15  cust_payment_terms      10000 non-null  object
#  16  isOpen                  10000 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(3), object(7)
# memory usage: 1.3+ MB

# %%
X_main_test["posting_date"]= pd.to_datetime(X_main_test["posting_date"])
X_main_test["document_create_date"]= pd.to_datetime(X_main_test.document_create_date,format='%Y%m%d')
X_main_test["baseline_create_date"]= pd.to_datetime(X_main_test.baseline_create_date,format='%Y%m%d')
#### Converting into datetime format

# %%
X_main_test.rename(columns={"document_create_date.1":"document_create_date1"}, inplace=True)

# %%
X_main_test["document_create_date1"]= pd.to_datetime(X_main_test.document_create_date1,format='%Y%m%d')

# %%
X_main_test.drop("document_create_date1",axis=1,inplace=True)
X_main_test.drop("area_business",axis=1,inplace=True)

# %%
X_main_test.business_code.value_counts()
# Out:
# U001    9178
# CA02     731
# U013      62
# U002      25
# U005       4
# Name: business_code, dtype: int64

# %%
X_main_test["business_code"]= np.where(X_main_test["business_code"].isin(["U005"]),"Others",X_main_test["business_code"])

# %%
X_main_test.sort_values(by=["posting_date"],inplace=True)

# %%
X_main_test.rename(columns={"document type":"document_type"}, inplace=True)

# %%
X_main_test.posting_id.value_counts()
# Out:
# 1.0    10000
# Name: posting_id, dtype: int64

# %%
X_main_test.rename(columns={"isOpen":"is_open"}, inplace=True)

# %%
X_main_test.is_open.value_counts()
# Out:
# 1    10000
# Name: is_open, dtype: int64

# %%
X_main_test.drop("posting_id",axis=1,inplace=True)
X_main_test.drop("is_open",axis=1,inplace=True)

# %%
X_main_test.drop("invoice_currency",axis=1,inplace=True)

# %%
#removing baseline_create_date as it has the same values of posting_date
X_main_test.drop("baseline_create_date",axis=1,inplace=True)
#removing document_type as it has an array of same values "RV".
X_main_test.drop("document_type",axis=1,inplace=True)

# %%
X_main_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 24437 to 37286
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   business_code         10000 non-null  object
#  1   cust_number           10000 non-null  object
#  2   name_customer         10000 non-null  object
#  3   buisness_year         10000 non-null  int32
#  4   doc_id                10000 non-null  int32
#  5   posting_date          10000 non-null  datetime64[ns]
#  6   document_create_date  10000 non-null  datetime64[ns]
#  7   due_in_date           10000 non-null  datetime64[ns]
#  8   total_open_amount     10000 non-null  float64
#  9   cust_payment_terms    10000 non-null  object
# dtypes: datetime64[ns](3), float64(1), int32(2), object(4)
# memory usage: 781.2+ KB

# %%
name_customer_enc = LabelEncoder()
name_customer_enc.fit(X_main_test["name_customer"])
X_main_test["name_customer_enc"]=name_customer_enc.transform(X_main_test["name_customer"])

# %%
X_main_test.drop(["name_customer"],inplace=True,axis=1)

# %%
def dropfet(col , traindf = X_main_test):
    traindf.drop(col,inplace=True,axis=1)
    return traindf

# %%
X_main_test["year_posting_date"]= X_main_test["posting_date"].dt.year
X_main_test["day_posting_date"]= X_main_test["posting_date"].dt.day
X_main_test["month_posting_date"]= X_main_test["posting_date"].dt.month

X_main_test["year_due_in_date"]= X_main_test["due_in_date"].dt.year
X_main_test["day_due_in_date"]= X_main_test["due_in_date"].dt.day
X_main_test["month_due_in_date"]= X_main_test["due_in_date"].dt.month

X_main_test["year_document_create_date"]= X_main_test["document_create_date"].dt.year
X_main_test["day_document_create_date"]= X_main_test["document_create_date"].dt.day
X_main_test["month_document_create_date"]= X_main_test["document_create_date"].dt.month

# %%
X_main_test = dropfet(["document_create_date"])
X_main_test = dropfet(["due_in_date"])
X_main_test = dropfet(["posting_date"])

# %%
cust_payment_terms_enc = LabelEncoder()
cust_payment_terms_enc.fit(X_main_test["cust_payment_terms"])
X_main_test["cust_payment_terms_enc"]=cust_payment_terms_enc.transform(X_main_test["cust_payment_terms"])

# %%
X_main_test= dropfet(["cust_payment_terms"])

# %%
mixed_cust_num="cust_number"
mixed_num_in_cust_num= mixed_cust_num + "_numerical"
mixed_label_in_cust_num= mixed_cust_num + "_label"

# %%
X_main_test[mixed_num_in_cust_num]=X_main_test[mixed_cust_num].str.extract('(\d+)')

# %%
X_main_test[mixed_label_in_cust_num]=X_main_test[mixed_cust_num].str[:3]

# %%
X_main_test["cust_number_numerical"]=X_main_test.cust_number_numerical.astype(int)

# %%
cust_number_label_enc = LabelEncoder()
cust_number_label_enc.fit(X_main_test["cust_number_label"])
X_main_test["cust_number_label_enc"]=cust_number_label_enc.transform(X_main_test["cust_number_label"])

# %%
X_main_test = dropfet(["cust_number"])
X_main_test = dropfet(["cust_number_label"])

# %%
business_code_enc = LabelEncoder()
business_code_enc.fit(X_main_test["business_code"])
X_main_test["business_code_enc"]=business_code_enc.transform(X_main_test["business_code"])

# %%
X_main_test = dropfet(["business_code"])

# %%
X_main_test.columns
# Out:
# Index(['buisness_year', 'doc_id', 'total_open_amount', 'name_customer_enc',
#        'year_posting_date', 'day_posting_date', 'month_posting_date',
#        'year_due_in_date', 'day_due_in_date', 'month_due_in_date',
#        'year_document_create_date', 'day_document_create_date',
#        'month_document_create_date', 'cust_payment_terms_enc',
#        'cust_number_numerical', 'cust_number_label_enc', 'business_code_enc'],
#       dtype='object')

# %%
X_train.columns
# Out:
# Index(['buisness_year', 'doc_id', 'total_open_amount', 'name_customer_enc',
#        'year_posting_date', 'day_posting_date', 'month_posting_date',
#        'year_due_in_date', 'day_due_in_date', 'month_due_in_date',
#        'year_document_create_date', 'day_document_create_date',
#        'month_document_create_date', 'cust_payment_terms_enc',
#        'cust_number_numerical', 'cust_number_label_enc', 'business_code_enc'],
#       dtype='object')

# %% [markdown]
# ### Both the dataframes are having same number of columns

# %% [markdown]
# ## The Finale

# %%
#Prediction 
final_result = regressor.predict(X_main_test)

# %%
final_result = pd.Series(final_result,name='Predicted_Delay')

# %%
#Resetting the index for merging the predicted series with it
Final = main_test.merge(final_result , on = X_main_test.index )
Final
# Out:
#       key_0 business_code cust_number       name_customer  buisness_year  \
# 0     24437          U001   200726979              BJ'S           2020.0
# 1     21000          U001   200780383     MEIJ associates         2020.0
# 2      2893          U001  0200776463       KROGE systems         2020.0
# 3     16444          U001   200769623        WAL-MAR corp         2020.0
# 4     10322          U001  0200769623          WAL-MAR co         2020.0
# ...     ...           ...         ...                 ...            ...
# 9995  30249          U001  0200418007       AM foundation         2020.0
# 9996  40940          U001  0200769623  WAL-MAR associates         2020.0
# 9997    731          U001  0200759878      SA corporation         2020.0
# 9998  35429          U001  0200769623  WAL-MAR associates         2020.0
# 9999  37286          U001  0200706844               WINC          2020.0
#
#             doc_id posting_date  document_create_date  document_create_date.1  \
# 0     1.930655e+09   2020-03-17              20200316                20200317
# 1     1.930855e+09   2020-05-04              20200503                20200504
# 2     1.930826e+09   2020-04-24              20200425                20200424
# 3     1.930677e+09   2020-03-23              20200321                20200323
# 4     1.930705e+09   2020-03-26              20200326                20200326
# ...            ...          ...                   ...                     ...
# 9995  1.930780e+09   2020-04-15              20200413                20200415
# 9996  1.930599e+09   2020-03-05              20200304                20200305
# 9997  1.930666e+09   2020-03-19              20200318                20200319
# 9998  1.930862e+09   2020-05-07              20200506                20200507
# 9999  1.930757e+09   2020-04-08              20200406                20200408
#
#      due_in_date invoice_currency document type  posting_id  area_business  \
# 0     2020-04-01              USD            RV         1.0            NaN
# 1     2020-05-19              USD            RV         1.0            NaN
# 2     2020-05-09              USD            RV         1.0            NaN
# 3     2020-04-07              USD            RV         1.0            NaN
# 4     2020-04-10              USD            RV         1.0            NaN
# ...          ...              ...           ...         ...            ...
# 9995  2020-04-30              USD            RV         1.0            NaN
# 9996  2020-03-20              USD            RV         1.0            NaN
# 9997  2020-04-03              USD            RV         1.0            NaN
# 9998  2020-05-22              USD            RV         1.0            NaN
# 9999  2020-04-23              USD            RV         1.0            NaN
#
#       total_open_amount  baseline_create_date cust_payment_terms  \
# 0                387.69            20200317.0               NAA8
# 1              41352.28            20200504.0               NAA8
# 2               2915.48            20200424.0               NAA8
# 3              13902.00            20200323.0               NAH4
# 4               3270.04            20200326.0               NAH4
# ...                 ...                   ...                ...
# 9995             644.80            20200415.0               NAA8
# 9996           16463.85            20200305.0               NAH4
# 9997           47269.22            20200319.0               NAH4
# 9998           25109.62            20200507.0               NAH4
# 9999            5880.96            20200408.0               NAA8
#
#         invoice_id  isOpen  Predicted_Delay
# 0     1.930655e+09       1         0.898752
# 1     1.930855e+09       1         0.898752
# 2     1.930826e+09       1         0.898752
# 3     1.930677e+09       1         0.898752
# 4     1.930705e+09       1         0.898752
# ...            ...     ...              ...
# 9995  1.930780e+09       1         2.634146
# 9996  1.930599e+09       1         0.898752
# 9997  1.930666e+09       1         2.634146
# 9998  1.930862e+09       1         0.898752
# 9999  1.930757e+09       1         0.898752
#
# [10000 rows x 20 columns]

# %%
Final["Predicted_Delay"].round()
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 9995    3.0
# 9996    1.0
# 9997    3.0
# 9998    1.0
# 9999    1.0
# Name: Predicted_Delay, Length: 10000, dtype: float64

# %%
Final["Predicted_Delay"]=Final.Predicted_Delay.astype(int)

# %%
Final["Predicted_Delay"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    2
# 9996    0
# 9997    2
# 9998    0
# 9999    0
# Name: Predicted_Delay, Length: 10000, dtype: int32

# %%
from datetime import timedelta
Final['predicted_payment_date']= Final['due_in_date'] + pd.to_timedelta(Final['Predicted_Delay'],'d')

# %%
Final
# Out:
#       key_0 business_code cust_number       name_customer  buisness_year  \
# 0     24437          U001   200726979              BJ'S           2020.0
# 1     21000          U001   200780383     MEIJ associates         2020.0
# 2      2893          U001  0200776463       KROGE systems         2020.0
# 3     16444          U001   200769623        WAL-MAR corp         2020.0
# 4     10322          U001  0200769623          WAL-MAR co         2020.0
# ...     ...           ...         ...                 ...            ...
# 9995  30249          U001  0200418007       AM foundation         2020.0
# 9996  40940          U001  0200769623  WAL-MAR associates         2020.0
# 9997    731          U001  0200759878      SA corporation         2020.0
# 9998  35429          U001  0200769623  WAL-MAR associates         2020.0
# 9999  37286          U001  0200706844               WINC          2020.0
#
#             doc_id posting_date  document_create_date  document_create_date.1  \
# 0     1.930655e+09   2020-03-17              20200316                20200317
# 1     1.930855e+09   2020-05-04              20200503                20200504
# 2     1.930826e+09   2020-04-24              20200425                20200424
# 3     1.930677e+09   2020-03-23              20200321                20200323
# 4     1.930705e+09   2020-03-26              20200326                20200326
# ...            ...          ...                   ...                     ...
# 9995  1.930780e+09   2020-04-15              20200413                20200415
# 9996  1.930599e+09   2020-03-05              20200304                20200305
# 9997  1.930666e+09   2020-03-19              20200318                20200319
# 9998  1.930862e+09   2020-05-07              20200506                20200507
# 9999  1.930757e+09   2020-04-08              20200406                20200408
#
#      due_in_date invoice_currency document type  posting_id  area_business  \
# 0     2020-04-01              USD            RV         1.0            NaN
# 1     2020-05-19              USD            RV         1.0            NaN
# 2     2020-05-09              USD            RV         1.0            NaN
# 3     2020-04-07              USD            RV         1.0            NaN
# 4     2020-04-10              USD            RV         1.0            NaN
# ...          ...              ...           ...         ...            ...
# 9995  2020-04-30              USD            RV         1.0            NaN
# 9996  2020-03-20              USD            RV         1.0            NaN
# 9997  2020-04-03              USD            RV         1.0            NaN
# 9998  2020-05-22              USD            RV         1.0            NaN
# 9999  2020-04-23              USD            RV         1.0            NaN
#
#       total_open_amount  baseline_create_date cust_payment_terms  \
# 0                387.69            20200317.0               NAA8
# 1              41352.28            20200504.0               NAA8
# 2               2915.48            20200424.0               NAA8
# 3              13902.00            20200323.0               NAH4
# 4               3270.04            20200326.0               NAH4
# ...                 ...                   ...                ...
# 9995             644.80            20200415.0               NAA8
# 9996           16463.85            20200305.0               NAH4
# 9997           47269.22            20200319.0               NAH4
# 9998           25109.62            20200507.0               NAH4
# 9999            5880.96            20200408.0               NAA8
#
#         invoice_id  isOpen  Predicted_Delay predicted_payment_date
# 0     1.930655e+09       1                0             2020-04-01
# 1     1.930855e+09       1                0             2020-05-19
# 2     1.930826e+09       1                0             2020-05-09
# 3     1.930677e+09       1                0             2020-04-07
# 4     1.930705e+09       1                0             2020-04-10
# ...            ...     ...              ...                    ...
# 9995  1.930780e+09       1                2             2020-05-02
# 9996  1.930599e+09       1                0             2020-03-20
# 9997  1.930666e+09       1                2             2020-04-05
# 9998  1.930862e+09       1                0             2020-05-22
# 9999  1.930757e+09       1                0             2020-04-23
#
# [10000 rows x 21 columns]

# %% [markdown]
# # Bucketization

# %%
def bucketization(x):
    if x<0:
        return('(< 0) Days')
    if x in range(0,16):
        return('(0-15) Days')
    elif x in range(16,31):
        return('(16-30) Days')
    elif x in range(31,45):
        return('(31-45) Days')
    elif x in range(45,60):
        return('(45-60) Days')
    else:
        return('(> 60) Days')

# %%
Final = Final.reset_index(drop=True)
Final['DELAY BUCKET(DAYS)']= pd.Series([bucketization(x=Final['Predicted_Delay'][i])  for i in range(len(Final))])
bucket_mapper = {'(< 0) Days':0,'(0-15) Days':1,'(16-30) Days':2,'(31-45) Days':4,'(45-60) Days':5,'(> 60) Days':6}
Final['delay_bucket_id'] = Final['DELAY BUCKET(DAYS)'].map(bucket_mapper)
Final.columns
# Out:
# Index(['key_0', 'business_code', 'cust_number', 'name_customer',
#        'buisness_year', 'doc_id', 'posting_date', 'document_create_date',
#        'document_create_date.1', 'due_in_date', 'invoice_currency',
#        'document type', 'posting_id', 'area_business', 'total_open_amount',
#        'baseline_create_date', 'cust_payment_terms', 'invoice_id', 'isOpen',
#        'Predicted_Delay', 'predicted_payment_date', 'DELAY BUCKET(DAYS)',
#        'delay_bucket_id'],
#       dtype='object')

# %%
Final['DELAY BUCKET(DAYS)'].value_counts()
# Out:
# (0-15) Days     9319
# (< 0) Days       521
# (31-45) Days     156
# (16-30) Days       4
# Name: DELAY BUCKET(DAYS), dtype: int64

# %% [markdown]
# # Finally the prediction is done!

# %%
Final
# Out:
#       key_0 business_code cust_number       name_customer  buisness_year  \
# 0     24437          U001   200726979              BJ'S           2020.0
# 1     21000          U001   200780383     MEIJ associates         2020.0
# 2      2893          U001  0200776463       KROGE systems         2020.0
# 3     16444          U001   200769623        WAL-MAR corp         2020.0
# 4     10322          U001  0200769623          WAL-MAR co         2020.0
# ...     ...           ...         ...                 ...            ...
# 9995  30249          U001  0200418007       AM foundation         2020.0
# 9996  40940          U001  0200769623  WAL-MAR associates         2020.0
# 9997    731          U001  0200759878      SA corporation         2020.0
# 9998  35429          U001  0200769623  WAL-MAR associates         2020.0
# 9999  37286          U001  0200706844               WINC          2020.0
#
#             doc_id posting_date  document_create_date  document_create_date.1  \
# 0     1.930655e+09   2020-03-17              20200316                20200317
# 1     1.930855e+09   2020-05-04              20200503                20200504
# 2     1.930826e+09   2020-04-24              20200425                20200424
# 3     1.930677e+09   2020-03-23              20200321                20200323
# 4     1.930705e+09   2020-03-26              20200326                20200326
# ...            ...          ...                   ...                     ...
# 9995  1.930780e+09   2020-04-15              20200413                20200415
# 9996  1.930599e+09   2020-03-05              20200304                20200305
# 9997  1.930666e+09   2020-03-19              20200318                20200319
# 9998  1.930862e+09   2020-05-07              20200506                20200507
# 9999  1.930757e+09   2020-04-08              20200406                20200408
#
#      due_in_date invoice_currency document type  posting_id  area_business  \
# 0     2020-04-01              USD            RV         1.0            NaN
# 1     2020-05-19              USD            RV         1.0            NaN
# 2     2020-05-09              USD            RV         1.0            NaN
# 3     2020-04-07              USD            RV         1.0            NaN
# 4     2020-04-10              USD            RV         1.0            NaN
# ...          ...              ...           ...         ...            ...
# 9995  2020-04-30              USD            RV         1.0            NaN
# 9996  2020-03-20              USD            RV         1.0            NaN
# 9997  2020-04-03              USD            RV         1.0            NaN
# 9998  2020-05-22              USD            RV         1.0            NaN
# 9999  2020-04-23              USD            RV         1.0            NaN
#
#       total_open_amount  baseline_create_date cust_payment_terms  \
# 0                387.69            20200317.0               NAA8
# 1              41352.28            20200504.0               NAA8
# 2               2915.48            20200424.0               NAA8
# 3              13902.00            20200323.0               NAH4
# 4               3270.04            20200326.0               NAH4
# ...                 ...                   ...                ...
# 9995             644.80            20200415.0               NAA8
# 9996           16463.85            20200305.0               NAH4
# 9997           47269.22            20200319.0               NAH4
# 9998           25109.62            20200507.0               NAH4
# 9999            5880.96            20200408.0               NAA8
#
#         invoice_id  isOpen  Predicted_Delay predicted_payment_date  \
# 0     1.930655e+09       1                0             2020-04-01
# 1     1.930855e+09       1                0             2020-05-19
# 2     1.930826e+09       1                0             2020-05-09
# 3     1.930677e+09       1                0             2020-04-07
# 4     1.930705e+09       1                0             2020-04-10
# ...            ...     ...              ...                    ...
# 9995  1.930780e+09       1                2             2020-05-02
# 9996  1.930599e+09       1                0             2020-03-20
# 9997  1.930666e+09       1                2             2020-04-05
# 9998  1.930862e+09       1                0             2020-05-22
# 9999  1.930757e+09       1                0             2020-04-23
#
#      DELAY BUCKET(DAYS)  delay_bucket_id
# 0           (0-15) Days                1
# 1           (0-15) Days                1
# 2           (0-15) Days                1
# 3           (0-15) Days                1
# 4           (0-15) Days                1
# ...                 ...              ...
# 9995        (0-15) Days                1
# 9996        (0-15) Days                1
# 9997        (0-15) Days                1
# 9998        (0-15) Days                1
# 9999        (0-15) Days                1
#
# [10000 rows x 23 columns]

# %% [markdown]
# ### Exported the final dataframe to csv

# %%
#Final.to_csv('H2HBABBA1529_final1.csv', sep='\t')
